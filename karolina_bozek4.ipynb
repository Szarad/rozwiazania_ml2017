# %%
import matplotlib.pyplot as plt
from sklearn import datasets
iris = datasets.load_iris()
X_iris, y_iris = iris.data, iris.target
print X_iris.shape, y_iris.shape
print X_iris[0], y_iris[0]
plt.scatter(X_iris[:,1],X_iris[:,2],c=y_iris)
plt.show()
# Out:
# (150, 4) (150,)
# [ 5.1  3.5  1.4  0.2] 0

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
digits = load_digits()
X_d, y_d = digits.data, digits.target
print X_d.shape, y_d.shape
print X_d[0], y_d[0]
plt.scatter(X_d[:,1],X_d[:,2],c=y_d)
plt.show()
# Out:
# (1797, 64) (1797,)
# [  0.   0.   5.  13.   9.   1.   0.   0.   0.   0.  13.  15.  10.  15.   5.
#    0.   0.   3.  15.   2.   0.  11.   8.   0.   0.   4.  12.   0.   0.   8.
#    8.   0.   0.   5.   8.   0.   0.   9.   8.   0.   0.   4.  11.   0.   1.
#   12.   7.   0.   0.   2.  14.   5.  10.  12.   0.   0.   0.   0.   6.  13.
#   10.   0.   0.   0.] 0

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_olivetti_faces
faces = fetch_olivetti_faces()
X_f, y_f = faces.data, faces.target
print X_f.shape, y_f.shape
print X_f[0], y_f[0]
plt.scatter(X_f[:,1],X_f[:,2],c=y_f)
plt.show()
# Out:
# (400, 4096) (400,)
# [ 0.30991736  0.36776859  0.41735536 ...,  0.15289256  0.16115703
#   0.1570248 ] 0

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
boston = datasets.load_boston()
X_b, y_b = boston.data, boston.target
plt.scatter(X_b[:,1],X_b[:,2],c=y_b)
plt.show()
